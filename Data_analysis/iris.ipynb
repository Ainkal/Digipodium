# %%
import pandas as pd

# %%
book={
    'title' : ['absd','sjsu','okey','gnu'],
      'athour' : ['tiger','minsa', 'sosjuya','chisiya'], 
      'id ':[1,45,26,42]
}
pd.DataFrame(book)
# Out:
#   title   athour  id
# 0  absd    tiger    1
# 1  sjsu    minsa   45
# 2  okey  sosjuya   26
# 3   gnu  chisiya   42

# %%
movie=[
    {'title':'gollmall','hero': 'Ajay', 'language':'hindi'},
    {'title':'kanak','hero': 'allu', 'language':'telugu'},
    {'title':'surya','hero': 'Akay', 'language':'kannada','trika':87}
]

pd.DataFrame(movie)
# Out:
#       title  hero language  trika
# 0  gollmall  Ajay    hindi    NaN
# 1     kanak  allu   telugu    NaN
# 2     surya  Akay  kannada   87.0

# %%
import seaborn as sns

# %%
#sns.get_dataset_names()

# %%
df=sns.load_dataset('iris')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
print(df.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
print(df.tail())
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
print(df.shape)     # (rows, columns)
# Out:
# (150, 5)

# %%
print(df.columns)   # Column names
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None

# %%
print(df.describe())
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# * # Intermediat panadas # *

# %%
# selection 

print(df.iloc[0])
# Out:
# sepal_length       5.1
# sepal_width        3.5
# petal_length       1.4
# petal_width        0.2
# species         setosa
# Name: 0, dtype: object

# %%
print(df.iloc[0:3])
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
print(df.loc[0,'species'])
# Out:
# setosa

# %%
df.iloc[[1,3,4],[0,2,3]]#selection by giving index of rowss and coumns
# Out:
#    sepal_length  petal_length  petal_width
# 1           4.9           1.4          0.2
# 3           4.6           1.5          0.2
# 4           5.0           1.4          0.2

# %% [markdown]
# # * single column selection
#      -dictionary like selection
#      -object like selection

# %%
print(df['sepal_length']) #selectted single column
#dicttioannaryy like selectionn
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64

# %%
df.sepal_width  #object like selesction
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
print(df[['sepal_length','species']]) #smultiple columns selection
# Out:
#      sepal_length    species
# 0             5.1     setosa
# 1             4.9     setosa
# 2             4.7     setosa
# 3             4.6     setosa
# 4             5.0     setosa
# ..            ...        ...
# 145           6.7  virginica
# 146           6.3  virginica
# 147           6.5  virginica
# 148           6.2  virginica
# 149           5.9  virginica
#
# [150 rows x 2 columns]

# %%
df.iloc[[2,3,5,7,9],[1,3,4]]

#shows the selected rows and colmns
# Out:
#    sepal_width  petal_width species
# 2          3.2          0.2  setosa
# 3          3.1          0.2  setosa
# 5          3.9          0.4  setosa
# 7          3.4          0.2  setosa
# 9          3.1          0.1  setosa

# %%
#filtering data from dataset

larger_sepal=df[df['sepal_width']>3.5]
print(larger_sepal)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 14            5.8          4.0           1.2          0.2     setosa
# 15            5.7          4.4           1.5          0.4     setosa
# 16            5.4          3.9           1.3          0.4     setosa
# 18            5.7          3.8           1.7          0.3     setosa
# 19            5.1          3.8           1.5          0.3     setosa
# 21            5.1          3.7           1.5          0.4     setosa
# 22            4.6          3.6           1.0          0.2     setosa
# 32            5.2          4.1           1.5          0.1     setosa
# 33            5.5          4.2           1.4          0.2     setosa
# 37            4.9          3.6           1.4          0.1     setosa
# ...

# %%
#filtering with multiple conditions
larger_petal=df[(df['petal_length']>5) & (df['petal_width']>2)]
larger_petal
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 100           6.3          3.3           6.0          2.5  virginica
# 102           7.1          3.0           5.9          2.1  virginica
# 104           6.5          3.0           5.8          2.2  virginica
# 105           7.6          3.0           6.6          2.1  virginica
# 109           7.2          3.6           6.1          2.5  virginica
# 112           6.8          3.0           5.5          2.1  virginica
# 114           5.8          2.8           5.1          2.4  virginica
# 115           6.4          3.2           5.3          2.3  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# 120           6.9          3.2           5.7          2.3  virginica
# 124           6.7          3.3           5.7          2.1  virginica
# 128           6.4          2.8           5.6          2.1  virginica
# ...

# %% [markdown]
# * # # Sorting dataset

# %%
df_sort=df.sort_values(by='sepal_width',ascending=True)
df_sort
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 60            5.0          2.0           3.5          1.0  versicolor
# 62            6.0          2.2           4.0          1.0  versicolor
# 119           6.0          2.2           5.0          1.5   virginica
# 68            6.2          2.2           4.5          1.5  versicolor
# 87            6.3          2.3           4.4          1.3  versicolor
# ..            ...          ...           ...          ...         ...
# 5             5.4          3.9           1.7          0.4      setosa
# 14            5.8          4.0           1.2          0.2      setosa
# 32            5.2          4.1           1.5          0.1      setosa
# 33            5.5          4.2           1.4          0.2      setosa
# 15            5.7          4.4           1.5          0.4      setosa
#
# [150 rows x 5 columns]

# %% [markdown]
# * # Manipulationn andd cleaning of data
#      - removing rows and coluumns
#      - renaming columns
#      - addingg columns
#      - changing datatypes
#      - handling missing  values
#      - dropping missinng values
#      - using apply() method

# %%
df_sort=df_sort.drop(columns='species')

df_sort=df_sort.drop(index=62)
df_sort
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 60            5.0          2.0           3.5          1.0
# 119           6.0          2.2           5.0          1.5
# 68            6.2          2.2           4.5          1.5
# 87            6.3          2.3           4.4          1.3
# 93            5.0          2.3           3.3          1.0
# ..            ...          ...           ...          ...
# 5             5.4          3.9           1.7          0.4
# 14            5.8          4.0           1.2          0.2
# 32            5.2          4.1           1.5          0.1
# 33            5.5          4.2           1.4          0.2
# 15            5.7          4.4           1.5          0.4
#
# [149 rows x 4 columns]

# %%
#rensming columns
df_sort.rename(columns={'sepal_length':'Sl','sepal_width':'Sw','petal_length':'Pl','petal_width':'Pw'},inplace=True)
df_sort
# Out:
#       Sl   Sw   Pl   Pw
# 60   5.0  2.0  3.5  1.0
# 119  6.0  2.2  5.0  1.5
# 68   6.2  2.2  4.5  1.5
# 87   6.3  2.3  4.4  1.3
# 93   5.0  2.3  3.3  1.0
# ..   ...  ...  ...  ...
# 5    5.4  3.9  1.7  0.4
# 14   5.8  4.0  1.2  0.2
# 32   5.2  4.1  1.5  0.1
# 33   5.5  4.2  1.4  0.2
# 15   5.7  4.4  1.5  0.4
#
# [149 rows x 4 columns]

# %%
df_sort['new_clmn']=df_sort['Sl']*2
df_sort
# Out:
#       Sl   Sw   Pl   Pw  new_clmn
# 60   5.0  2.0  3.5  1.0      10.0
# 119  6.0  2.2  5.0  1.5      12.0
# 68   6.2  2.2  4.5  1.5      12.4
# 87   6.3  2.3  4.4  1.3      12.6
# 93   5.0  2.3  3.3  1.0      10.0
# ..   ...  ...  ...  ...       ...
# 5    5.4  3.9  1.7  0.4      10.8
# 14   5.8  4.0  1.2  0.2      11.6
# 32   5.2  4.1  1.5  0.1      10.4
# 33   5.5  4.2  1.4  0.2      11.0
# 15   5.7  4.4  1.5  0.4      11.4
#
# [149 rows x 5 columns]

# %%
df_sort.groupby('Sl').mean()
# Out:
#            Sw        Pl        Pw  new_clmn
# Sl
# 4.3  3.000000  1.100000  0.100000       8.6
# 4.4  3.033333  1.333333  0.200000       8.8
# 4.5  2.300000  1.300000  0.300000       9.0
# 4.6  3.325000  1.325000  0.225000       9.2
# 4.7  3.200000  1.450000  0.200000       9.4
# 4.8  3.180000  1.580000  0.200000       9.6
# 4.9  2.950000  2.266667  0.550000       9.8
# 5.0  3.120000  1.840000  0.430000      10.0
# 5.1  3.477778  1.722222  0.400000      10.2
# 5.2  3.425000  2.075000  0.475000      10.4
# 5.3  3.700000  1.500000  0.200000      10.6
# 5.4  3.550000  2.033333  0.516667      10.8
# 5.5  2.842857  3.228571  0.900000      11.0
# 5.6  2.816667  4.200000  1.416667      11.2
# 5.7  3.100000  3.587500  1.100000      11.4
# 5.8  2.885714  4.071429  1.400000      11.6
# 5.9  3.066667  4.700000  1.700000      11.8
# 6.0  2.840000  4.780000  1.600000      12.0
# 6.1  2.850000  4.750000  1.416667      12.2
# 6.2  2.825000  4.750000  1.725000      12.4
# ...

# %%
df_agg = df_sort.groupby('Sl').agg({
    'Pl': ['mean', 'max', 'min'],  # Apply mean, max, and min to Pl
    'Sw': 'sum'  # Sum up the sw for each Sl
})

df_agg
# Out:
#            Pl              Sw
#          mean  max  min   sum
# Sl
# 4.3  1.100000  1.1  1.1   3.0
# 4.4  1.333333  1.4  1.3   9.1
# 4.5  1.300000  1.3  1.3   2.3
# 4.6  1.325000  1.5  1.0  13.3
# 4.7  1.450000  1.6  1.3   6.4
# 4.8  1.580000  1.9  1.4  15.9
# 4.9  2.266667  4.5  1.4  17.7
# 5.0  1.840000  3.5  1.2  31.2
# 5.1  1.722222  3.0  1.4  31.3
# 5.2  2.075000  3.9  1.4  13.7
# 5.3  1.500000  1.5  1.5   3.7
# 5.4  2.033333  4.5  1.3  21.3
# 5.5  3.228571  4.4  1.3  19.9
# 5.6  4.200000  4.9  3.6  16.9
# 5.7  3.587500  5.0  1.5  24.8
# 5.8  4.071429  5.1  1.2  20.2
# 5.9  4.700000  5.1  4.2   9.2
# 6.0  4.780000  5.1  4.5  14.2
# 6.1  4.750000  5.6  4.0  17.1
# 6.2  4.750000  5.4  4.3  11.3
# 6.3  5.133333  6.0  4.4  25.7
# 6.4  5.157143  5.6  4.3  20.7
# 6.5  5.240000  5.8  4.6  15.0
# 6.6  4.500000  4.6  4.4   5.9
# 6.7  5.262500  5.8  4.4  24.4
# 6.8  5.400000  5.9  4.8   9.0
# 6.9  5.275000  5.7  4.9  12.5
# 7.0  4.700000  4.7  4.7   3.2
# 7.1  5.900000  5.9  5.9   3.0
# ...

# %% [markdown]
# # handling missing values

# %%
#handling missing values
import pandas as pd
import numpy as np

# %%
ds = {
    'A':[10,20,np.nan,30,np.nan],
    'B':[1,np.nan,3,np.nan,6],
    'C':[49,56,np.nan,9,54]
}

data=pd.DataFrame(ds)



#checkinng null values in data set
print(data.isnull())
#print the sum of null values per column
print(data.isnull().sum())
# Out:
#        A      B      C
# 0  False  False  False
# 1  False   True  False
# 2   True  False   True
# 3  False   True  False
# 4   True  False  False
# A    2
# B    2
# C    1
# dtype: int64

# %%
#removing rows with null values
data.dropna(inplace=True)
data
# Out:
#       A    B     C
# 0  10.0  1.0  49.0

# %%
data=pd.DataFrame(ds)
data
# Out:
#       A    B     C
# 0  10.0  1.0  49.0
# 1  20.0  NaN  56.0
# 2   NaN  3.0   NaN
# 3  30.0  NaN   9.0
# 4   NaN  6.0  54.0

# %%
#removing columns with null vslues
data.dropna(axis=1,inplace=True )
data
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
data
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
dt = {
    'A':[10,20,np.nan,30,np.nan],
    'B':[1,np.nan,3,np.nan,6],
    'C':[49,56,np.nan,9,54]
}

dts=pd.DataFrame(dt)

# %%
dts.fillna(0,inplace=True)
#replace nan with 0
dts
# Out:
#       A    B     C
# 0  10.0  1.0  49.0
# 1  20.0  0.0  56.0
# 2   0.0  3.0   0.0
# 3  30.0  0.0   9.0
# 4   0.0  6.0  54.0

# %%
dts=pd.DataFrame(dt)
#dts.copy() 
#fill with column mean
dts['A']=dts['A'].fillna(dts['A'].mean())

dts
# Out:
#       A    B     C
# 0  10.0  1.0  49.0
# 1  20.0  NaN  56.0
# 2  20.0  3.0   NaN
# 3  30.0  NaN   9.0
# 4  20.0  6.0  54.0

# %%
#fill with column median
dts['B']=dts['B'].fillna(dts['B'].median())
dts
# Out:
#       A    B     C
# 0  10.0  1.0  49.0
# 1  20.0  3.0  56.0
# 2  20.0  3.0   NaN
# 3  30.0  3.0   9.0
# 4  20.0  6.0  54.0

# %%
#fill with forward fill (previous value)
#dts['C']=dts['C'].fillna(method='ffill')

dts['C'] = dts['C'].ffill()  # ✅ Correct approach

#fill with backward fill (next value)
#dts['B']=dts['B'].fillna(method='bfill')
dts['B'] = dts['B'].bfill()  # ✅ Correct approach
dts
# Out:
#       A    B     C
# 0  10.0  1.0  49.0
# 1  20.0  3.0  56.0
# 2  20.0  3.0  56.0
# 3  30.0  3.0   9.0
# 4  20.0  6.0  54.0

# %% [markdown]
#  * Apply() function

# %%
#using apply()

dts['A']=dts['A'].apply(lambda x: x*x)
dts
# Out:
#        A    B     C
# 0  100.0  1.0  49.0
# 1  400.0  3.0  56.0
# 2  400.0  3.0  56.0
# 3  900.0  3.0   9.0
# 4  400.0  6.0  54.0
